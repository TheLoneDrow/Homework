# %%
s_dersler = []

def note_calc():
    a = 0
    b = 0
    c = 0
    ic = {"Midterm": a, "Final": b, "Project": c}
    note_course = input("As announced, because of the Covid-19 Crisis, we will take only one of your courses into the account when we are calculatin your Final Score. Please enter the course, which you will be held responsible for.")
    if not note_course in s_dersler:
        print("You have entered a course you are not taking, please restart the prgram")
    
    
    if note_course in s_dersler:
        a = float(input("Please enter your Midterm note:"))
        b = float(input("Please enter your Final note:"))
        c = float(input("Please enter your Project note:"))
    
    if  0 <= a <=100 and 0 <= b <=100 and 0 <= c <=100:
        a1 = a*0.3
        b1 = b*0.5
        c1 = c*0.2
        end_note = a1 + b1 + c1
        
        ic["Midterm"] = a
        ic["Final"] = b
        ic["Project"] = c
        
        if end_note < 30:
            print("You have failed.")
            print("Your final score is: "+ str(end_note))
        if end_note >= 30:
            print("Congratulations, you have passed!" + "Your Final Score is: " + str(end_note)) 
            print("Your final notes are: ")
            print(ic)
    else:
        print("You have entered an unvalid value, please restart the programm.")
        








x = 3
print ("Your name is Mahmut Öztürk, you will need to enter your name.")
while x > 0:
    name = input("Please Enter Your Name")
    if name == "Mahmut Öztürk":
        print("Welcome! Loading...")
        break
    else:
        print("Please try again.")
        x = x-1
    if x <= 0:
        print("Please restart the programm and try again.")
        break

while x > 0:
    print("In this Programm you need to take minimum 3 and maximum 5 courses, otherwise you will fail. Please choose your courses from the list below:")
    dersler = ["Maths", "Physics", "Chemistry", "Biologie", "German Language", "Russian"]
    print(dersler)
    
    print("Now please enter the courses you want to take, when you don't want to take anymore courses, enter 'quit'")
    z = input("Enter the courses you choose")
    
    if z in s_dersler:
        print("You cannot choose the same course twice! Please enter a course you have not choosen")
        s_dersler.pop(-1)
    if z in dersler:
        s_dersler.append(z)
    if z == "quit":
        if len(s_dersler)<3 or len(s_dersler)>5:
            print("You have failed cause you have either selected less than 3 or more than 5 courses.")
            break
        try:
            print("You have choosen the courses: ", s_dersler, "You have totally choosen", len(s_dersler), "courses.")
            s_dersler.pop(-1)
            note_calc()
            break
        except(IndexError):
            print("Please do not quit before choosing courses, programm is restarting...")
            break
    if not z in dersler:
        print("You have choosen a course not in the list, programm is restarting...")
        break
# Out:
# Your name is Mahmut Öztürk, you will need to enter your name.
